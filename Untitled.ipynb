# %%
import requests

# %%
url = "https://graph.instagram.com/v25.0/me/messages"
headers = {'Authorization': 'Bearer IGAATI8zcb86NBZAFlDWmxCMC1kLVFJWWdkSFctS0ZAFYlcyS0xaSzVybGxxMUJIaFUtaUU5cGJpUHNxODRJdzhtVHpOZAjNqQVRjWVNUM3NfSTZAJX1laaHFNakIxT05ZAM19nSEdGM1JvZAk5JNHdicks0MXlGVzBjdERrSjg3R2h6WQZDZD',
           'Content-Type': 'application/json'
 }
payload = {
    "message": {
        "text": "Hello World"
    },
    "recipient": {
        "id": "2024111648524538"
    }
  }
response=requests.post(url,headers=headers,json=payload)

# %%
response.json()
# Out:
# {'recipient_id': '2024111648524538',
#  'message_id': 'aWdfZAG1faXRlbToxOklHTWVzc2FnZAUlEOjE3ODQxNDIzOTU4NDk3NjQ3OjM0MDI4MjM2Njg0MTcxMDMwMTI0NDI3NjI4MjMwOTU3NjU3NzE3MjozMjgzMDQ5MzUyNDI0ODUxMDU2NTkwOTgyNTk2ODkzMDgxNgZDZD'}

# %%
curl -X POST \
  'https://graph.instagram.com/v25.0/me/messages' \
  -H 'Authorization: Bearer IGAATI8zcb86NBZAFlDWmxCMC1kLVFJWWdkSFctS0ZAFYlcyS0xaSzVybGxxMUJIaFUtaUU5cGJpUHNxODRJdzhtVHpOZAjNqQVRjWVNUM3NfSTZAJX1laaHFNakIxT05ZAM19nSEdGM1JvZAk5JNHdicks0MXlGVzBjdERrSjg3R2h6WQZDZD' \
  -H 'Content-Type: application/json' \
  -d '{
    "message": {
        "text": "Hello World"
    },
    "recipient": {
        "id": ""
    }
  }'
